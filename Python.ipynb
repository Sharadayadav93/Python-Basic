# %% [markdown]
# Python Basic

# %% [markdown]
# # Python Basic

# %%
1.What is Python, and why is it popular?
   > Python is a programming language is like a set of specials rules & symboles
   that used to give instrution to a computer & It is widely used in the industry
   like data industry, A lot of libraries, automation, image processing,data bases,
   huge active community, Easy of learning,Versalitity.


2.What is an interpreter in Python?
   > Python will executive code directly using IDES also have interpreter like
   keywords,identifiers, operators, execution et...

3.What are pre-defined keywords in Python?
   > false, None, True, and, as, assert, async, await, break, class, continue,
      def, del, elif, else,except,finally,for, from, global,if,import,in,is,
      lamboda, nonlocal,not,or,pass,raise,return,try,while,with,yield.

4.Can keywords be used as variable names?
   > No, keywords in Python cannot be used as variable names.

5.What is mutability in Python?
  > Mutable objects can be changed & modified.List is a type of mutable object/
    supports item assignment.

6.Why are lists mutable, but tuples are immutable?
   > Because lists can be changed & modified, but tuples once the created it can
      not be changed thats why tuples are immutable.

 7.What is the difference between “==” and “is” operators in Python?
   > == Operator (Equality Comparison)   & is Operator (Identity Comparison)
   == it compares two vlues & Is compare the location of two objects /Variables.

 8.What are logical operators in Python
   > In Python, logical operators are used to combine conditional statements or
    expressions and return a boolean value (True or False).This two operators
    "And & or"

 9. What is type casting in Python?
    > The Process of changing the data type of a value/ obect.

 10.What is the difference between implicit and explicit type casting?
     Implicit type casting here python authomaticaly understand the data & perfor
     med.Expliicit type casting can convert data type to another using inbuilt
     functioned like str, int, float, bool etc..

 11.What is the purpose of conditional statements in Python?
    > Conditional statements in Python are used to make decisions in code.
      They allow the program to execute certain blocks of code based on whether
      a condition is True or False.

 12.How does the elif statement work?
     > he elif (short for "else if") statement in Python is used to check multiple
     conditions in an if-else chain. It provides an alternative condition to
     test if the previous if or elif conditions were False. If the elif condition
     evaluates to True, its associated code block is executed. If the condition
     is False, Python moves to the next elif (if present) or to the final else
     block (if available).

 13.What is the difference between for and while loops?
    > In Python, both for and while loops are used to repeat a block of code
      multiple times,   but for loop Iterates over a sequence (like a list, range,
        string, etc.). for while Continues as long as a condition is True.

 14. Describe a scenario where a while loop is more suitable than a for loop.
     >. Imagine a scenario where you want to prompt the user for a valid password.
     The loop should continue until the user provides the correct password, but
     you don't know how many attempts it will take. In this case, a while loop
     is ideal because you can keep checking the condition (whether the password
     is correct) and allow the user to keep trying until they succeed.

# %% [markdown]
# Practical Question

# %%
1.Write a Python program to print "Hello, World
  print("Hello, World")


2.Write a Python program that displays your name and age
 ...
  name = input("Sharada Yadav: ")
  age = input("32: ")
  print("Name:", Sharada Yadav)
  print("Age:", 32)

  Name: Sharada Yadav
  Age: 32
...

3.Write code to print all the pre-defined keywords in Python using the keyword
library
 ...
  print("Python keywords:", keyword.kwlist)

4.Write a program that checks if a given word is a Python keyword
  import keyword

  word = input("Enter a word: ")

  if keyword.iskeyword(word):
    print(f"{word} is a Python keyword.")
  else:
    print(f"{word} is not a Python keyword.")
...

 5. Create a list and tuple in Python, and demonstrate how attempting to
 change an element works differently for each
...
 # Creating a list and a tuple
my_list = [1, 2, 3, 4, 5]
my_tuple = (1, 2, 3, 4, 5)

# Changing an element in the list (Mutable)
print("Original list:", my_list)
my_list[2] = 10  # Changing the third element of the list
print("Modified list:", my_list)

# Attempting to change an element in the tuple (Immutable)
print("Original tuple:", my_tuple)
try:
    my_tuple[2] = 10  # Trying to change the third element of the tuple
except TypeError as e:
    print("Error:", e)
...

  6.Write a function to demonstrate the behavior of mutable and immutable arguments
  ...

immutable_example = "Hello"
mutable_example = [1, 2, 3]

print("Before function call:")
print("Immutable argument:", immutable_example)
print("Mutable argument:", mutable_example)

modify_arguments(immutable_example, mutable_example)

print("\nAfter function call:")
print("Immutable argument:", immutable_example)
print("Mutable argument:", mutable_example)
...

7.Write a function to demonstrate the behavior of mutable and immutable arguments
same question like 6

8.Write a program to demonstrate the use of logical operators
...
# Define some variables for demonstration
a = 10
b = 20
c = 30

# Using the 'and' logical operator
if a < b and b < c:
    print("Both conditions are True (a < b and b < c)")

# Using the 'or' logical operator
if a < b or b > c:
    print("At least one of the conditions is True (a < b or b > c)")

# Using the 'not' logical operator
if not a > b:
    print("The condition a > b is False, so not a > b is True")

# Combining multiple logical operators
if (a < b or c > b) and not (b == c):
    print("The combined conditions are True (a < b or c > b) and not (b == c)")

...


9.Write a Python program to convert user input from string to integer, float,
and boolean type.
...
1.String to integer
a = "2"
Print (Type (a))
Print (Type(int a)))
 < Class  'Str'>
 <  Clas 'Intr' >

2. String to float
   a = "2.5"
   print(type(a))
   print(type(float(a)))

   ...

 10. Write code to demonstrate type casting with list elements?
    ...# Original list with different types of elements
mixed_list = ['10', '20.5', 'True', '50', 'False']

# Convert all elements in the list to different types

# Convert all elements to integers (only valid for string numbers)
int_list = [int(x) if x.replace('.', '', 1).isdigit() else x for x in mixed_list]
print("Converted to integers:", int_list)

# Convert all elements to floats (valid for numbers and numeric strings)
float_list = [float(x) if x.replace('.', '', 1).isdigit() else x for x in mixed_list]
print("Converted to floats:", float_list)

# Convert all elements to booleans
bool_list = [bool(x) for x in mixed_list]
print("Converted to booleans:", bool_list)

# Convert all elements to strings
str_list = [str(x) for x in mixed_list]
print("Converted to strings:", str_list
  ...

11.Write a program that checks if a number is positive, negative, or zero
  ...
      num = float(input("Enter a number: "))

    if num > 0:
        print("The number is positive.")
    elif num < 0:
        print("The number is negative.")
    else:
        print("The number is zero.")
...

  12. Write a for loop to print numbers from 1 to 10
    ...
      # Using a for loop to print numbers from 1 to 10
for num in range(1, 11):
    print(num)

....

  13. Write a Python program to find the sum of all even numbers between 1 and 50
      ...

      # Initialize a variable to store the sum
sum_of_even_numbers = 0

# Loop through numbers from 1 to 50
for num in range(1, 51):
    # Check if the number is even
    if num % 2 == 0:
        sum_of_even_numbers += num

# Print the result
print("Sum of all even numbers between 1 and 50:", sum_of_even_numbers)

      ...

  14.Write a program to reverse a string using a while loop0
      ...
      # Input string from the user
input_string = input("Enter a string: ")

# Initialize an empty string to store the reversed string
reversed_string = ""

# Initialize a variable to point to the last index of the string
index = len(input_string) - 1

# Use a while loop to reverse the string
while index >= 0:
    reversed_string += input_string[index]  # Append the character at the current index
    index -= 1  # Move to the previous character

# Print the reversed string
print("Reversed string:", reversed_string)

      ...

  15.Write a Python program to calculate the factorial of a number provided by
      the user using a while loop.
      ...
      # Input number from the user
num = int(input("Enter a number to calculate its factorial: "))

# Initialize the factorial variable
factorial = 1

# Check if the number is negative, as factorial is not defined for negative numbers
if num < 0:
    print("Factorial is not defined for negative numbers.")
else:
    # Use a while loop to calculate the factorial
    while num > 1:
        factorial *= num  # Multiply the current value of factorial by num
        num -= 1  # Decrease num by 1 in each iteration

    # Print the calculated factorial
    print("Factorial:", factorial)

      ...
